# %%
df = pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/aucs.csv")
df["far_neg_higher?"] = df["far_neg_only_aucs"] > df["close_neg_only_aucs"]
df
# Out:
#    Unnamed: 0        keyword   all_aps  all_aucs  far_neg_only_aps  \
# 0           0         àpɾí  0.077434  0.430000          0.081550
# 1           1      ðɔ̀mɔ̀cɔ̀  0.104252  0.600000          0.113136
# 2           2       lɛ́ŋgɛ́n  0.211862  0.617273          0.219175
# 3           3     ŋɔ̀ɽíŋgɔ́  0.102024  0.515455          0.113367
# 4           4         mùðù  0.177879  0.605455          0.182660
# 5           5         ùɾnɔ̀  0.074333  0.416364          0.081097
# 6           6        ðàŋàl  0.118646  0.623636          0.127830
# 7           7   kə̀və̀lɛ̀ðɔ́  0.150177  0.524545          0.161800
# 8           8         kàŋú  0.133653  0.480000          0.138016
# 9           9  íŋgá_nɔ̀nà  0.130706  0.660000          0.152536
#
#    far_neg_only_aucs  close_neg_only_aps  close_neg_only_aucs  far_neg_higher?
# 0              0.408            0.622284                 0.65            False
# ...

# %%
import pandas as pd
from IPython.display import display
df = pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/mùðù.csv")

# sorting by a column
df = df.sort_values(by=["record_type","wctc_loss"], ascending = [True, False])

df.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd
from IPython.display import display
df = pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/mùðù.csv")

# sorting by a column
df = df.sort_values(by=["wctc_loss"], ascending = False)

df.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...
