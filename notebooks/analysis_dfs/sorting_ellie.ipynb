# %%
import pandas as pd
df_aucs = pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/aucs.csv")
df_aucs["far_neg_higher?"] = df_aucs["far_neg_only_aucs"] > df_aucs["close_neg_only_aucs"]
df_aucs
# Out:
#    Unnamed: 0        keyword   all_aps  all_aucs  far_neg_only_aps  \
# 0           0         àpɾí  0.077434  0.430000          0.081550
# 1           1      ðɔ̀mɔ̀cɔ̀  0.104252  0.600000          0.113136
# 2           2       lɛ́ŋgɛ́n  0.211862  0.617273          0.219175
# 3           3     ŋɔ̀ɽíŋgɔ́  0.102024  0.515455          0.113367
# 4           4         mùðù  0.177879  0.605455          0.182660
# 5           5         ùɾnɔ̀  0.074333  0.416364          0.081097
# 6           6        ðàŋàl  0.118646  0.623636          0.127830
# 7           7   kə̀və̀lɛ̀ðɔ́  0.150177  0.524545          0.161800
# 8           8         kàŋú  0.133653  0.480000          0.138016
# 9           9  íŋgá_nɔ̀nà  0.130706  0.660000          0.152536
#
#    far_neg_only_aucs  close_neg_only_aps  close_neg_only_aucs  far_neg_higher?
# 0              0.408            0.622284                 0.65            False
# ...

# %%
pd.set_option("display.float_format", "{:.4f}".format)
df_aucs.columns = df_aucs.columns.str.strip()
df_aucs.sort_values(by=["all_aps"], ascending = False)
# Out:
#    Unnamed: 0        keyword  all_aps  all_aucs  far_neg_only_aps  \
# 2           2       lɛ́ŋgɛ́n   0.2119    0.6173            0.2192
# 4           4         mùðù   0.1779    0.6055            0.1827
# 7           7   kə̀və̀lɛ̀ðɔ́   0.1502    0.5245            0.1618
# 8           8         kàŋú   0.1337    0.4800            0.1380
# 9           9  íŋgá_nɔ̀nà   0.1307    0.6600            0.1525
# 6           6        ðàŋàl   0.1186    0.6236            0.1278
# 1           1      ðɔ̀mɔ̀cɔ̀   0.1043    0.6000            0.1131
# 3           3     ŋɔ̀ɽíŋgɔ́   0.1020    0.5155            0.1134
# 0           0         àpɾí   0.0774    0.4300            0.0816
# 5           5         ùɾnɔ̀   0.0743    0.4164            0.0811
#
#    far_neg_only_aucs  close_neg_only_aps  close_neg_only_aucs  far_neg_higher?
# 2             0.6260              0.6948               0.5300             True
# 4             0.5930              0.7632               0.7300            False
# ...

# %%
import pandas as pd
from IPython.display import display
df_muthu= pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/mùðù.csv")

# sorting by record type and wctc loss
df_muthu = df_muthu.sort_values(by=["record_type","wctc_loss"], ascending = [True, False])

df_muthu.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
# sorting by wctc loss
df_muthu = df_muthu.sort_values(by=["wctc_loss"], ascending = False)

df_muthu.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
df_urno= pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/ùɾnɔ̀.csv")

# sorting by record type and wctc loss
df_urno = df_urno.sort_values(by=["wctc_loss"], ascending = [False])

df_urno.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
df_apri= pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/àpɾí.csv")

# sorting by record type and wctc loss
df_apri = df_apri.sort_values(by=["wctc_loss"], ascending = [False])

df_apri.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
df_thomocho= pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/ðɔ̀mɔ̀cɔ̀.csv")

# sorting by record type and wctc loss
df_thomocho = df_thomocho.sort_values(by=["wctc_loss"], ascending = [False])

df_thomocho.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
df_kavletho= pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/kə̀və̀lɛ̀ðɔ́.csv")

# sorting by record type and wctc loss
df_kavletho = df_kavletho.sort_values(by=["wctc_loss"], ascending = [False])

df_kavletho.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
df_kanu= pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/kàŋú.csv")

# sorting by record type and wctc loss
df_kanu = df_kanu.sort_values(by=["wctc_loss"], ascending = [False])

df_kanu.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
df_thanal= pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/ðàŋàl.csv")

# sorting by record type and wctc loss
df_thanal = df_thanal.sort_values(by=["wctc_loss"], ascending = [False])

df_thanal.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
df_lengen= pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/lɛ́ŋgɛ́n.csv")

# sorting by record type and wctc loss
df_lengen = df_lengen.sort_values(by=["wctc_loss"], ascending = [False])

df_lengen.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
df_inga_nona = pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/íŋgá_nɔ̀nà.csv")

# sorting by record type and wctc loss
df_inga_nona = df_inga_nona.sort_values(by=["wctc_loss"], ascending = [False])

df_inga_nona.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...

# %%
df_noringo = pd.read_csv("/home/ekuznetsova/tira_kws/notebooks/analysis_dfs/ŋɔ̀ɽíŋgɔ́.csv")

# sorting by record type and wctc loss
df_noringo = df_noringo.sort_values(by=["wctc_loss"], ascending = [False])

df_noringo.style.set_properties(subset=["sentence"],
                        **{"min-width":"200px",
                           "max-width":"400px"}
                        )
# Out:
# <style type="text/css">
# ...
