# %%
import pandas as pd

# %%
test_df = pd.read_csv('large_tot_df.csv')
test_df
# Out:
#       Unnamed: 0                                  sentence     record_type  \
# 0              0       kúkù ŋgá kɛ̀cí ɛ́ɾáðɛ́ nɛ̀ rî        negative
# 1              1        láɾl̀à ðə́ɟíðɔ́ dìjɔ́ nd̪ɔ̀bà        negative
# 2              2      ðɔ̀mɔ̀cɔ̀ ðápàt̪ɛ̀ àpɾíɲá ɛ̀ðɛ̀  close_negative
# 3              3                   t̪átɛ́ ùnɛ́ɾɛ́ újɛ̀l        negative
# 4              4      kńnà àpɾí jɛ́ àɾɔ́ ðówɛ́ íðɔ̀        positive
# ...          ...                                       ...             ...
# 1195           1  àn èdɛ̀ɽì kɛ̀ɾɔ́ íŋgá ŕnà ŋrɔ̂bà  close_negative
# 1196           2  àn èdɛ̀ɽì kɛ̀ɾɔ́ íŋgá ŕnà ŋrɔ̂bà        negative
# 1197           3            íŋgá nɔ́nà lúɔ́ t̪ɔ́wɜ̀nì        positive
# 1198           4      ŋgá nɔ́nà ìt̪rɛ́ lə̀və́r nd̪ɔ̀bà  close_negative
# 1199           5       kúkù ŋgá kɛ̀cí ɛ́ɾáðɛ́ nɛ̀ rî        negative
#
#             keyword         loss  wctc_loss  \
# ...

# %%
test_df['pred_strings'][0]
# Out:
# '˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞ɱʷɱ˞˞˞ɗ ˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞ʷ˞˞˞˞˞˞˞˞ɨ˞˞˞˞˞˞˞˞ɱ˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞ˠ˞˞˞˞˞˞˞˞˞˞˞˞˞˞ɸ˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞˞'
