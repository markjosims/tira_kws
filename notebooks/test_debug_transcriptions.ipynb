# %%
import pandas as pd

# %%
test_df = pd.read_csv('tot_df.csv')
test_df
# Out:
#      Unnamed: 0                                  sentence     record_type  \
# 0             0        láɾl̀à ðə́ɟíðɔ́ dìjɔ́ nd̪ɔ̀bà        negative
# 1             1                   t̪átɛ́ ùnɛ́ɾɛ́ újɛ̀l        negative
# 2             2               ŋgá nɔ́nà lɔ́mɛ́ nd̪ɔ̀bà  close_negative
# 3             3          ágá nɔ́nà àɽàŋgár nd̪ɔ̀bà  close_negative
# 4             4  ŋgá nɔ́nà ŋòɽón nɛ̀ lə̀və́r nd̪ɔ̀bà  close_negative
# ..          ...                                       ...             ...
# 115           1  àn èdɛ̀ɽì kɛ̀ɾɔ́ íŋgá ŕnà ŋrɔ̂bà  close_negative
# 116           2  àn èdɛ̀ɽì kɛ̀ɾɔ́ íŋgá ŕnà ŋrɔ̂bà        negative
# 117           3            íŋgá nɔ́nà lúɔ́ t̪ɔ́wɜ̀nì        positive
# 118           4      ŋgá nɔ́nà ìt̪rɛ́ lə̀və́r nd̪ɔ̀bà  close_negative
# 119           5       kúkù ŋgá kɛ̀cí ɛ́ɾáðɛ́ nɛ̀ rî        negative
#
#            keyword        loss  wctc_loss  \
# ...

# %%
test_df['pred_strings'][0]
# Out:
# 'sa<sos/eos><sos/eos><sos/eos><sos/eos>s<sos/eos>ɓ<sos/eos><sos/eos>ɓ<sos/eos><sos/eos><sos/eos><sos/eos><sos/eos>œ<sos/eos>sɓ<sos/eos>ŋ<sos/eos>s<sos/eos><sos/eos><sos/eos><sos/eos><sos/eos><sos/eos>ʕrrrws̃̃̃̃̃̃ŋ̃ŋ̃ⱱ̃̃̃̃̃ŋ̃̃ŋhŋrhaɓaʢhhra̚hrrrwar̚hrã̃̃̃̃̃̃ssŋ̃ss<sos/eos>ssʝsʝ<sos/eos><sos/eos><sos/eos><sos/eos>s<sos/eos><sos/eos>aa<sos/eos>s<sos/eos>arhssrhhhggrɒrh̚rɓɓɓsaŋhs̃̃̃a<sos/eos>aasʰsrsɓsʝhssshsʰas̃ss̃a<sos/eos>g<sos/eos><sos/eos><sos/eos><sos/eos><sos/eos><sos/eos><sos/eos><sos/eos><sos/eos>s<sos/eos><sos/eos><sos/eos><sos/eos><sos/eos><sos/eos>sss<sos/eos><sos/eos>'
